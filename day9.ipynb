# %%
class Student:
    name="amish chaudhary"
s1=Student()
print(s1.name)


class car:
    color="Blue"
    brand="BYD"
car1=car()
print(car1.color)
print(car1.brand)
# Out:
# amish chaudhary
# Blue
# BYD
