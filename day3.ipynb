# %% [markdown]
# ## Nesting

# %%
age=34
if(age>=18):
    if(age>=80):
       print("cannot drive")
    else:
       print("can drive")
else:
    print("cannot drive")
# Out:
# can drive

# %% [markdown]
# ## WAP to check if a number entered by the user is odd or even.

# %%
a=int(input("enter any number:"))
r=a%2
if(r==0):
    print("entered number is even.")
else:
    print("entered number is odd.")
# Out:
# entered number is even.

# %% [markdown]
# ## WAP to find the greatest of 3 number enteresd by the user.

# %%
a=int(input("enter any number"))
b=int(input("enter any number"))
c=int(input("enter any number"))
if(c<a>b):
    print("a is greater.")
elif(a<b>c):
    print("b is greater.")
else:
    print("c is greater.")
# Out:
# a is greater.

# %% [markdown]
# ## WAP to check if a number is a  multiple of 7 or not .

# %%
a=int(input("enter any number."))
r=a%7
if(r==0):
    print("enteredd number is  multiple of 7.")
else:
    print("entered number is not multiple of 7.")
# Out:
# enteredd number is  multiple of 7.
