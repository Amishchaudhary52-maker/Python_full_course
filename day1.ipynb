# %%
print("hello world")
# Out:
# hello world

# %%
print("hello!","Amish chauhdary")
# Out:
# hello! Amish chauhdary

# %%
name="Amish chaudhary"
age=18
GPA=3.67
print(name)
print(age)
print(GPA)
# Out:
# Amish chaudhary
# 18
# 3.67

# %%
name="amish chaudhary"
age=18
GPA=3.67
print(type(name))
print(type(age))
print(type(GPA))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
age=23
old=False
a=None
print(type(age))
print(type(old))
print(type(a))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
a=int(input("enter any number"))
b=int(input("enter any number"))
c=a+b
print("sum:",c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 a=int(input("enter any number"))
#       2 b=int(input("enter any number"))
#       3 c=a+b
#       4 print("sum:",c)
#
# ValueError: invalid literal for int() with base 10: '3.4'

# %%
a=int(input("enter any number"))
b=int(input("enter any number"))
c=a-b
#differenc
print("diff:",c)
# Out:
# diff: 2

# %% [markdown]
# ## Arithmetic operator

# %%
a=4
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b) # a^b
# Out:
# 6
# 2
# 8
# 2.0
# 0
# 16

# %% [markdown]
# ## Relational opetaror

# %%
a=50
b=20
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# ## Assignment operator

# %%
a=10
b=a
print("a=",b)
print("b=",b)
# Out:
# a= 10
# b= 10

# %% [markdown]
# ## Logical operator

# %%
print(not True) #false
print(not False) #Ture
value1=True
value2=True 
print("AND operator:",value1 and value2) #Ture if both True
print("Or operator:",value1 or value2) #Ture if one is true
a=50
b=20
print("AND:",(a>b) and (a==b))
print("OR:",(a>b) or (a==b))
# Out:
# False
# True
# AND operator: True
# Or operator: True
# AND: False
# OR: True

# %% [markdown]
# ## Type conversion

# %%
a="2"
b=4.25
c=int(a)
print(b+c)
print(type(c))
# Out:
# 6.25
# <class 'int'>

# %%
a=2
b=str(a)
print(type(b))
# Out:
# <class 'str'>

# %% [markdown]
# WAP to inpt 2 number and print their sum.

# %%
a=int(input("enter any number:"))
b=int(input("enter any number:"))
sum=a+b
print(sum)
# Out:
# 5

# %% [markdown]
# ## WAP to input side of a square  and print  its area

# %%
a=float(input("enter the side of square"))
area =a**2
print(area)
# Out:
# 4.0

# %% [markdown]
# ## WAP to input   2 floating point number and print their average.

# %%
a=float(input("enter any number"))
b=float(input("enter any number"))
avg=(a+b)/2
print("average:",avg)
# Out:
# average: 3.9000000000000004

# %% [markdown]
# ## WAp  to input 2 int number a and b  print true  if a is greater than or equal to b , if  not print false.

# %%
a=int(input("enter any number"))
b=int(input("enter any number"))
print(a>=b)
# Out:
# False
