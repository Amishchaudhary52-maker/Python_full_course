# %%
str1=" my name is Amish chaudhary.\nCosmos college of Management and Technology" #\n for next line.
str2=" my name is Amish chaudhary.\tCosmos college of Management and Technology" # \t for space.
print(str1)
print(str2)
print(str1+str2) # concatination
len1=(len(str1))
print(len1)
# Out:
#  my name is Amish chaudhary.
# Cosmos college of Management and Technology
#  my name is Amish chaudhary.	Cosmos college of Management and Technology
#  my name is Amish chaudhary.
# Cosmos college of Management and Technology my name is Amish chaudhary.	Cosmos college of Management and Technology
# 72

# %%
str1="cosmos_college"
ch=str1[1]
print(ch)
# Out:
# o

# %%
str="cosmos_college"
print(str[1:4])
print(str[:13])
print(str[1:])
# Out:
# osm
# cosmos_colleg
# osmos_college

# %%
str="APPLE"
print(str[-3:-1])
# Out:
# PL

# %%
str="iam a coder."
print(str.endswith("er."))
print(str.capitalize())
print(str.replace("coder","programmer"))
print(str.find("coder"))
print(str.count("iam"))
# Out:
# True
# Iam a coder.
# iam a programmer.
# 6
# 1

# %% [markdown]
# ## WAP to input user's first name and print its length.

# %%
str=input("enter your first name:")
length=len(str)
print(length)
# Out:
# 5

# %% [markdown]
# ## WAP to find the occurance of $ in string

# %%
str="Amish $$$"
print(str.count("$"))
# Out:
# 3

# %%
age=17
if(age>=18):
    print("you can vote.")
else:
    print("you can't vote.")
# Out:
# you can't vote.

# %%
marks=float(input("enter your obtain marks:"))
if(marks>=90):
    print("A+")
elif(90>marks>=80 ):
    print("A")
elif(80>marks>=70):
    print("B+")
elif(70>marks>=60):
    print("B")
elif(60>marks>=50):
    print("C+")
elif(50>marks>=35):
    print("C")
else:
    print("Failed")
# Out:
# C
